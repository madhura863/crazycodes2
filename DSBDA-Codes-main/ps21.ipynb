# %% [markdown]
# # Adult Dataset Visualization
# Visualization with objectives, labels and clean structure

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../DSBDALExam DataSets/Adult/adult.csv", header=None)

df.columns = [
    'age','workclass','fnlwgt','education','education-num',
    'marital-status','occupation','relationship','race','sex',
    'capital-gain','capital-loss','hours-per-week',
    'native-country','income'
]



df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# ## Histogram

# %%
# Objective: To visualize distribution of Age
print("Histogram Objective: To visualize distribution of Age")

plt.hist(df['age'], bins=20)
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# Histogram Objective: To visualize distribution of Age

# %% [markdown]
# ## Dot Plot

# %%
# Objective: To display individual Age values
print("Dot Plot Objective: To display individual Age values")

plt.plot(df['age'], '.', color='blue')
plt.title("Dot Plot of Age")
plt.xlabel("Index")
plt.ylabel("Age")
plt.show()
# Out:
# Dot Plot Objective: To display individual Age values

# %% [markdown]
# ## Bar Plot

# %%
# Objective: To compare Male and Female count
print("Bar Plot Objective: To compare Male and Female count")

sns.countplot(x='sex', data=df)
plt.title("Bar Plot of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Bar Plot Objective: To compare Male and Female count

# %% [markdown]
# ## Line Chart

# %%
# Objective: To show average working hours for each age
print("Line Chart Objective: To show average Hours per Week for each Age")

df_avg = df.groupby('age')['hours-per-week'].mean()

plt.plot(df_avg.index, df_avg.values)
plt.title("Average Hours per Week vs Age")
plt.xlabel("Age")
plt.ylabel("Average Hours per Week")
plt.show()
# Out:
# Line Chart Objective: To show average Hours per Week for each Age

# %% [markdown]
# ## Box Plot + Histogram + Scatter Plot

# %%
print("Combined Plot Objective: To visualize distribution, relationship and outliers")

plt.figure(figsize=(15, 5))

# Box Plot
plt.subplot(1, 3, 1)
sns.boxplot(x=df['hours-per-week'])
plt.title("Box Plot of Hours per Week")
plt.xlabel("Hours per Week")

# Histogram
plt.subplot(1, 3, 2)
plt.hist(df['hours-per-week'], bins=20)
plt.title("Histogram of Hours per Week")
plt.xlabel("Hours per Week")
plt.ylabel("Frequency")

# Scatter Plot
plt.subplot(1, 3, 3)
plt.scatter(df['age'], df['hours-per-week'])
plt.title("Scatter Plot: Age vs Hours per Week")
plt.xlabel("Age")
plt.ylabel("Hours per Week")

plt.tight_layout()
plt.show()
# Out:
# Combined Plot Objective: To visualize distribution, relationship and outliers

# %%
Visualize the census bureau databset(Adult data sets)by plotting the following graphs using
Python. (Define objective for every graph)
f. Histograms
g. Dot Plots
h. Bar Plots
i. Line Charts
j. Add Histogram and Scatter plot to box plot
