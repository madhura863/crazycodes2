# %% [markdown]
# # Adult Dataset Visualization (Set 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../DSBDALExam DataSets/Adult/adult.csv", header=None)

df.columns = [
    'age','workclass','fnlwgt','education','education-num',
    'marital-status','occupation','relationship','race','sex',
    'capital-gain','capital-loss','hours-per-week',
    'native-country','income'
]


df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# ## Histogram

# %%
print("Histogram Objective: To visualize distribution of Age")

plt.hist(df['age'], bins=20)
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# Histogram Objective: To visualize distribution of Age

# %% [markdown]
# ## Pie Chart

# %%
print("Pie Chart Objective: To show proportion of Income categories")

counts = df['income'].value_counts()
labels = counts.index

plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title("Income Distribution")
plt.show()
# Out:
# Pie Chart Objective: To show proportion of Income categories

# %% [markdown]
# ## Box Plot

# %%
print("Box Plot Objective: To detect outliers in Working Hours")

sns.boxplot(x=df['hours-per-week'])
plt.title("Box Plot of Hours per Week")
plt.xlabel("Hours per Week")
plt.show()
# Out:
# Box Plot Objective: To detect outliers in Working Hours

# %% [markdown]
# ## Scatter Plot

# %%
print("Scatter Plot Objective: To show relationship between Age and Working Hours")

plt.scatter(df['age'], df['hours-per-week'])
plt.title("Scatter Plot: Age vs Hours per Week")
plt.xlabel("Age")
plt.ylabel("Hours per Week")
plt.show()
# Out:
# Scatter Plot Objective: To show relationship between Age and Working Hours

# %% [markdown]
# ## Combined Plot

# %%
print("Combined Plot Objective: To show relationship and distribution together")

plt.figure(figsize=(12, 5))

# Scatter Plot
plt.subplot(1, 2, 1)
plt.scatter(df['age'], df['hours-per-week'])
plt.title("Scatter Plot")
plt.xlabel("Age")
plt.ylabel("Hours per Week")

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(y=df['hours-per-week'])
plt.title("Box Plot of Hours per Week")

plt.tight_layout()
plt.show()
# Out:
# Combined Plot Objective: To show relationship and distribution together

# %%
Visualize the census bureau databset(Adult data sets)by plotting the following graphs using
Python. (Define objective for every graph)
a. Histograms
b. Pie Charts
c. Box Plots
d. Scatter Plots
e. Add boxplots to a scatterplot
